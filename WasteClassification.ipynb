# %% [markdown]
# <a href="https://colab.research.google.com/github/cardstdani/WasteClassificationNeuralNetwork/blob/main/WasteClassification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Wed Jan  5 13:39:37 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.44       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   32C    P0    25W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import random
import math
import os
import cv2 as cv
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures, StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split

# %% [markdown]
# ##**Data Gathering and Preprocessing**

# %%
# !git clone https://github.com/cardstdani/WasteClassificationNeuralNetwork.git
# Out:
# Cloning into 'WasteClassificationNeuralNetwork'...
# remote: Enumerating objects: 5077, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (9/9), done.
# remote: Total 5077 (delta 4), reused 0 (delta 0), pack-reused 5068
# Receiving objects: 100% (5077/5077), 196.41 MiB | 29.11 MiB/s, done.
# Resolving deltas: 100% (5/5), done.

# %%
#LOAD DATA
DIR = "/content/WasteClassificationNeuralNetwork/WasteImagesDataset"
train_dataset = tf.keras.preprocessing.image_dataset_from_directory(DIR, validation_split=0.1, subset="training", seed=42, batch_size=128, smart_resize=True, image_size=(256, 256))
test_dataset = tf.keras.preprocessing.image_dataset_from_directory(DIR, validation_split=0.1, subset="validation", seed=42, batch_size=128, smart_resize=True, image_size=(256, 256))

classes = train_dataset.class_names
numClasses = len(train_dataset.class_names)
print(classes)

AUTOTUNE = tf.data.AUTOTUNE

train_dataset = train_dataset.prefetch(buffer_size=AUTOTUNE)
test_dataset = test_dataset.prefetch(buffer_size=AUTOTUNE)
# Out:
# Found 5078 files belonging to 9 classes.
# Using 4571 files for training.
# Found 5078 files belonging to 9 classes.
# Using 507 files for validation.
# ['Aluminium', 'Carton', 'Glass', 'Organic Waste', 'Other Plastics', 'Paper and Cardboard', 'Plastic', 'Textiles', 'Wood']

# %% [markdown]
# ##**Model Training**

# %%
baseModel = tf.keras.applications.MobileNetV3Large(input_shape=(256, 256,3), weights='imagenet', include_top=False, classes=numClasses)
for layers in baseModel.layers[:-6]:
  layers.trainable=False

last_output = baseModel.layers[-1].output
x = tf.keras.layers.Dropout(0.45) (last_output)
x = tf.keras.layers.GlobalAveragePooling2D()(x)
x = tf.keras.layers.BatchNormalization() (x)
x = tf.keras.layers.Dense(256, activation = tf.keras.activations.elu, kernel_regularizer=tf.keras.regularizers.l1(0.045), activity_regularizer=tf.keras.regularizers.l1(0.045),  kernel_initializer='he_normal')(x)
x = tf.keras.layers.Dropout(0.45) (x)
x = tf.keras.layers.Dense(numClasses, activation='softmax')(x)

model = tf.keras.Model(inputs=baseModel.input,outputs=x)
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.00125), loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), metrics=['accuracy'])

epochs = 50
lrCallback = tf.keras.callbacks.LearningRateScheduler(lambda epoch: 1e-3 * 10 ** (epoch / 30))
stepDecay = tf.keras.callbacks.LearningRateScheduler(lambda epoch: 0.1 * 0.1**math.floor(epoch / 6))
history = model.fit(train_dataset, validation_data=test_dataset, epochs=epochs, callbacks=[])
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not 224. Weights for input shape (224, 224) will be loaded as the default.
# Epoch 1/50
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1096: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   return dispatch_target(*args, **kwargs)
# 36/36 [==============================] - 14s 250ms/step - loss: 229.8705 - accuracy: 0.7042 - val_loss: 79.7820 - val_accuracy: 0.8876
# Epoch 2/50
# 36/36 [==============================] - 10s 226ms/step - loss: 32.0021 - accuracy: 0.7933 - val_loss: 8.5222 - val_accuracy: 0.5957
# Epoch 3/50
# 36/36 [==============================] - 10s 225ms/step - loss: 5.8862 - accuracy: 0.5681 - val_loss: 4.5838 - val_accuracy: 0.5779
# Epoch 4/50
# 36/36 [==============================] - 10s 226ms/step - loss: 4.4891 - accuracy: 0.5710 - val_loss: 4.3758 - val_accuracy: 0.5700
# Epoch 5/50
# 36/36 [==============================] - 10s 224ms/step - loss: 4.3943 - accuracy: 0.5690 - val_loss: 4.3053 - val_accuracy: 0.5957
# Epoch 6/50
# 36/36 [==============================] - 10s 225ms/step - loss: 4.3347 - accuracy: 0.5811 - val_loss: 4.2623 - val_accuracy: 0.6036
# Epoch 7/50
# 36/36 [==============================] - 10s 224ms/step - loss: 4.2904 - accuracy: 0.6047 - val_loss: 4.2111 - val_accuracy: 0.6252
# Epoch 8/50
# 36/36 [==============================] - 10s 224ms/step - loss: 4.2420 - accuracy: 0.6261 - val_loss: 4.1551 - val_accuracy: 0.6410
# Epoch 9/50
# 36/36 [==============================] - 10s 221ms/step - loss: 4.1945 - accuracy: 0.6694 - val_loss: 4.1169 - val_accuracy: 0.7258
# Epoch 10/50
# 36/36 [==============================] - 10s 225ms/step - loss: 4.1290 - accuracy: 0.7268 - val_loss: 4.0131 - val_accuracy: 0.7929
# Epoch 11/50
# 36/36 [==============================] - 10s 222ms/step - loss: 4.0590 - accuracy: 0.7703 - val_loss: 3.9298 - val_accuracy: 0.8383
# Epoch 12/50
# 36/36 [==============================] - 10s 227ms/step - loss: 3.9947 - accuracy: 0.8140 - val_loss: 3.8568 - val_accuracy: 0.8659
# Epoch 13/50
# 36/36 [==============================] - 10s 224ms/step - loss: 3.9215 - accuracy: 0.8484 - val_loss: 3.7797 - val_accuracy: 0.8935
# Epoch 14/50
# 36/36 [==============================] - 10s 223ms/step - loss: 3.8288 - accuracy: 0.8740 - val_loss: 3.7108 - val_accuracy: 0.8935
# Epoch 15/50
# 36/36 [==============================] - 10s 224ms/step - loss: 3.7790 - accuracy: 0.8886 - val_loss: 3.6569 - val_accuracy: 0.9093
# Epoch 16/50
# 36/36 [==============================] - 10s 221ms/step - loss: 3.7268 - accuracy: 0.9081 - val_loss: 3.6392 - val_accuracy: 0.9211
# Epoch 17/50
# 36/36 [==============================] - 10s 223ms/step - loss: 3.6517 - accuracy: 0.9131 - val_loss: 3.5156 - val_accuracy: 0.9290
# Epoch 18/50
# 36/36 [==============================] - 10s 225ms/step - loss: 3.6086 - accuracy: 0.9230 - val_loss: 3.4729 - val_accuracy: 0.9329
# Epoch 19/50
# 36/36 [==============================] - 10s 225ms/step - loss: 3.5843 - accuracy: 0.9315 - val_loss: 3.5126 - val_accuracy: 0.9467
# Epoch 20/50
# 36/36 [==============================] - 10s 225ms/step - loss: 3.5358 - accuracy: 0.9363 - val_loss: 3.4247 - val_accuracy: 0.9369
# Epoch 21/50
# 36/36 [==============================] - 10s 224ms/step - loss: 3.5006 - accuracy: 0.9403 - val_loss: 3.4163 - val_accuracy: 0.9290
# Epoch 22/50
# 36/36 [==============================] - 10s 226ms/step - loss: 3.4735 - accuracy: 0.9433 - val_loss: 3.3987 - val_accuracy: 0.9389
# Epoch 23/50
# 36/36 [==============================] - 10s 224ms/step - loss: 3.4089 - accuracy: 0.9554 - val_loss: 3.3612 - val_accuracy: 0.9448
# Epoch 24/50
# 36/36 [==============================] - 10s 224ms/step - loss: 3.4070 - accuracy: 0.9512 - val_loss: 3.3574 - val_accuracy: 0.9625
# Epoch 25/50
# 36/36 [==============================] - 10s 222ms/step - loss: 3.3685 - accuracy: 0.9584 - val_loss: 3.3427 - val_accuracy: 0.9606
# Epoch 26/50
# 36/36 [==============================] - 10s 223ms/step - loss: 3.3452 - accuracy: 0.9589 - val_loss: 3.2907 - val_accuracy: 0.9586
# Epoch 27/50
# 36/36 [==============================] - 10s 224ms/step - loss: 3.3513 - accuracy: 0.9600 - val_loss: 3.2670 - val_accuracy: 0.9408
# Epoch 28/50
# 36/36 [==============================] - 10s 222ms/step - loss: 3.3057 - accuracy: 0.9665 - val_loss: 3.2877 - val_accuracy: 0.9507
# Epoch 29/50
# 36/36 [==============================] - 10s 222ms/step - loss: 3.3095 - accuracy: 0.9654 - val_loss: 3.2690 - val_accuracy: 0.9487
# Epoch 30/50
# 36/36 [==============================] - 10s 223ms/step - loss: 3.2567 - accuracy: 0.9716 - val_loss: 3.2085 - val_accuracy: 0.9586
# Epoch 31/50
# 36/36 [==============================] - 10s 223ms/step - loss: 3.2752 - accuracy: 0.9696 - val_loss: 3.2460 - val_accuracy: 0.9507
# Epoch 32/50
# 36/36 [==============================] - 10s 225ms/step - loss: 3.2401 - accuracy: 0.9722 - val_loss: 3.2383 - val_accuracy: 0.9566
# Epoch 33/50
# 36/36 [==============================] - 10s 224ms/step - loss: 3.2070 - accuracy: 0.9779 - val_loss: 3.1658 - val_accuracy: 0.9566
# Epoch 34/50
# 36/36 [==============================] - 10s 224ms/step - loss: 3.1982 - accuracy: 0.9768 - val_loss: 3.1830 - val_accuracy: 0.9625
# Epoch 35/50
# 36/36 [==============================] - 10s 224ms/step - loss: 3.1962 - accuracy: 0.9812 - val_loss: 3.2345 - val_accuracy: 0.9566
# Epoch 36/50
# 36/36 [==============================] - 10s 224ms/step - loss: 3.1758 - accuracy: 0.9803 - val_loss: 3.1612 - val_accuracy: 0.9527
# Epoch 37/50
# 36/36 [==============================] - 10s 224ms/step - loss: 3.1672 - accuracy: 0.9814 - val_loss: 3.1423 - val_accuracy: 0.9527
# Epoch 38/50
# 36/36 [==============================] - 10s 227ms/step - loss: 3.1547 - accuracy: 0.9805 - val_loss: 3.1385 - val_accuracy: 0.9566
# Epoch 39/50
# 36/36 [==============================] - 10s 226ms/step - loss: 3.1090 - accuracy: 0.9845 - val_loss: 3.0918 - val_accuracy: 0.9606
# Epoch 40/50
# 36/36 [==============================] - 10s 223ms/step - loss: 3.1249 - accuracy: 0.9856 - val_loss: 3.1427 - val_accuracy: 0.9586
# Epoch 41/50
# 36/36 [==============================] - 10s 224ms/step - loss: 3.1059 - accuracy: 0.9845 - val_loss: 3.1653 - val_accuracy: 0.9586
# Epoch 42/50
# 36/36 [==============================] - 10s 225ms/step - loss: 3.1011 - accuracy: 0.9867 - val_loss: 3.1897 - val_accuracy: 0.9606
# Epoch 43/50
# 36/36 [==============================] - 10s 225ms/step - loss: 3.1160 - accuracy: 0.9851 - val_loss: 3.0569 - val_accuracy: 0.9665
# Epoch 44/50
# 36/36 [==============================] - 10s 223ms/step - loss: 3.1521 - accuracy: 0.9847 - val_loss: 3.0534 - val_accuracy: 0.9625
# Epoch 45/50
# 36/36 [==============================] - 10s 222ms/step - loss: 3.0530 - accuracy: 0.9873 - val_loss: 3.1304 - val_accuracy: 0.9507
# Epoch 46/50
# 36/36 [==============================] - 10s 222ms/step - loss: 3.0684 - accuracy: 0.9871 - val_loss: 3.1333 - val_accuracy: 0.9665
# Epoch 47/50
# 36/36 [==============================] - 10s 223ms/step - loss: 3.1002 - accuracy: 0.9873 - val_loss: 3.1173 - val_accuracy: 0.9467
# Epoch 48/50
# 36/36 [==============================] - 10s 224ms/step - loss: 3.0555 - accuracy: 0.9875 - val_loss: 3.0648 - val_accuracy: 0.9546
# Epoch 49/50
# 36/36 [==============================] - 10s 224ms/step - loss: 3.0404 - accuracy: 0.9884 - val_loss: 3.0865 - val_accuracy: 0.9546
# Epoch 50/50
# 36/36 [==============================] - 10s 224ms/step - loss: 3.0707 - accuracy: 0.9875 - val_loss: 3.0412 - val_accuracy: 0.9645

# %%
model.save("/content/model.h5")
model.summary()
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
# Model: "model_8"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_9 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  rescaling_8 (Rescaling)        (None, 256, 256, 3)  0           ['input_9[0][0]']
#
#  Conv (Conv2D)                  (None, 128, 128, 16  432         ['rescaling_8[0][0]']
#                                 )
#
#  Conv/BatchNorm (BatchNormaliza  (None, 128, 128, 16  64         ['Conv[0][0]']
#  tion)                          )
#
#  tf.__operators__.add_232 (TFOp  (None, 128, 128, 16  0          ['Conv/BatchNorm[0][0]']
#  Lambda)                        )
#
#  re_lu_320 (ReLU)               (None, 128, 128, 16  0           ['tf.__operators__.add_232[0][0]'
#                                 )                                ]
#
#  tf.math.multiply_232 (TFOpLamb  (None, 128, 128, 16  0          ['re_lu_320[0][0]']
#  da)                            )
#
#  multiply_168 (Multiply)        (None, 128, 128, 16  0           ['Conv/BatchNorm[0][0]',
#                                 )                                 'tf.math.multiply_232[0][0]']
#
#  expanded_conv/depthwise (Depth  (None, 128, 128, 16  144        ['multiply_168[0][0]']
#  wiseConv2D)                    )
#
#  expanded_conv/depthwise/BatchN  (None, 128, 128, 16  64         ['expanded_conv/depthwise[0][0]']
#  orm (BatchNormalization)       )
#
#  re_lu_321 (ReLU)               (None, 128, 128, 16  0           ['expanded_conv/depthwise/BatchNo
#                                 )                                rm[0][0]']
#
#  expanded_conv/project (Conv2D)  (None, 128, 128, 16  256        ['re_lu_321[0][0]']
#                                 )
#
#  expanded_conv/project/BatchNor  (None, 128, 128, 16  64         ['expanded_conv/project[0][0]']
#  m (BatchNormalization)         )
#
#  expanded_conv/Add (Add)        (None, 128, 128, 16  0           ['multiply_168[0][0]',
#                                 )                                 'expanded_conv/project/BatchNorm
#                                                                  [0][0]']
#
#  expanded_conv_1/expand (Conv2D  (None, 128, 128, 64  1024       ['expanded_conv/Add[0][0]']
#  )                              )
#
#  expanded_conv_1/expand/BatchNo  (None, 128, 128, 64  256        ['expanded_conv_1/expand[0][0]']
#  rm (BatchNormalization)        )
#
#  re_lu_322 (ReLU)               (None, 128, 128, 64  0           ['expanded_conv_1/expand/BatchNor
#                                 )                                m[0][0]']
#
#  expanded_conv_1/depthwise/pad   (None, 129, 129, 64  0          ['re_lu_322[0][0]']
#  (ZeroPadding2D)                )
#
#  expanded_conv_1/depthwise (Dep  (None, 64, 64, 64)  576         ['expanded_conv_1/depthwise/pad[0
#  thwiseConv2D)                                                   ][0]']
#
#  expanded_conv_1/depthwise/Batc  (None, 64, 64, 64)  256         ['expanded_conv_1/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  re_lu_323 (ReLU)               (None, 64, 64, 64)   0           ['expanded_conv_1/depthwise/Batch
#                                                                  Norm[0][0]']
#
#  expanded_conv_1/project (Conv2  (None, 64, 64, 24)  1536        ['re_lu_323[0][0]']
#  D)
#
#  expanded_conv_1/project/BatchN  (None, 64, 64, 24)  96          ['expanded_conv_1/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_2/expand (Conv2D  (None, 64, 64, 72)  1728        ['expanded_conv_1/project/BatchNo
#  )                                                               rm[0][0]']
#
#  expanded_conv_2/expand/BatchNo  (None, 64, 64, 72)  288         ['expanded_conv_2/expand[0][0]']
#  rm (BatchNormalization)
#
#  re_lu_324 (ReLU)               (None, 64, 64, 72)   0           ['expanded_conv_2/expand/BatchNor
#                                                                  m[0][0]']
#
#  expanded_conv_2/depthwise (Dep  (None, 64, 64, 72)  648         ['re_lu_324[0][0]']
#  thwiseConv2D)
#
#  expanded_conv_2/depthwise/Batc  (None, 64, 64, 72)  288         ['expanded_conv_2/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  re_lu_325 (ReLU)               (None, 64, 64, 72)   0           ['expanded_conv_2/depthwise/Batch
#                                                                  Norm[0][0]']
#
#  expanded_conv_2/project (Conv2  (None, 64, 64, 24)  1728        ['re_lu_325[0][0]']
#  D)
#
#  expanded_conv_2/project/BatchN  (None, 64, 64, 24)  96          ['expanded_conv_2/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_2/Add (Add)      (None, 64, 64, 24)   0           ['expanded_conv_1/project/BatchNo
#                                                                  rm[0][0]',
#                                                                   'expanded_conv_2/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_3/expand (Conv2D  (None, 64, 64, 72)  1728        ['expanded_conv_2/Add[0][0]']
#  )
#
#  expanded_conv_3/expand/BatchNo  (None, 64, 64, 72)  288         ['expanded_conv_3/expand[0][0]']
#  rm (BatchNormalization)
#
#  re_lu_326 (ReLU)               (None, 64, 64, 72)   0           ['expanded_conv_3/expand/BatchNor
#                                                                  m[0][0]']
#
#  expanded_conv_3/depthwise/pad   (None, 67, 67, 72)  0           ['re_lu_326[0][0]']
#  (ZeroPadding2D)
#
#  expanded_conv_3/depthwise (Dep  (None, 32, 32, 72)  1800        ['expanded_conv_3/depthwise/pad[0
#  thwiseConv2D)                                                   ][0]']
#
#  expanded_conv_3/depthwise/Batc  (None, 32, 32, 72)  288         ['expanded_conv_3/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  re_lu_327 (ReLU)               (None, 32, 32, 72)   0           ['expanded_conv_3/depthwise/Batch
#                                                                  Norm[0][0]']
#
#  expanded_conv_3/squeeze_excite  (None, 1, 1, 72)    0           ['re_lu_327[0][0]']
#  /AvgPool (GlobalAveragePooling
#  2D)
#
#  expanded_conv_3/squeeze_excite  (None, 1, 1, 24)    1752        ['expanded_conv_3/squeeze_excite/
#  /Conv (Conv2D)                                                  AvgPool[0][0]']
#
#  expanded_conv_3/squeeze_excite  (None, 1, 1, 24)    0           ['expanded_conv_3/squeeze_excite/
#  /Relu (ReLU)                                                    Conv[0][0]']
#
#  expanded_conv_3/squeeze_excite  (None, 1, 1, 72)    1800        ['expanded_conv_3/squeeze_excite/
#  /Conv_1 (Conv2D)                                                Relu[0][0]']
#
#  tf.__operators__.add_233 (TFOp  (None, 1, 1, 72)    0           ['expanded_conv_3/squeeze_excite/
#  Lambda)                                                         Conv_1[0][0]']
#
#  re_lu_328 (ReLU)               (None, 1, 1, 72)     0           ['tf.__operators__.add_233[0][0]'
#                                                                  ]
#
#  tf.math.multiply_233 (TFOpLamb  (None, 1, 1, 72)    0           ['re_lu_328[0][0]']
#  da)
#
#  expanded_conv_3/squeeze_excite  (None, 32, 32, 72)  0           ['re_lu_327[0][0]',
#  /Mul (Multiply)                                                  'tf.math.multiply_233[0][0]']
#
#  expanded_conv_3/project (Conv2  (None, 32, 32, 40)  2880        ['expanded_conv_3/squeeze_excite/
#  D)                                                              Mul[0][0]']
#
#  expanded_conv_3/project/BatchN  (None, 32, 32, 40)  160         ['expanded_conv_3/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_4/expand (Conv2D  (None, 32, 32, 120)  4800       ['expanded_conv_3/project/BatchNo
#  )                                                               rm[0][0]']
#
#  expanded_conv_4/expand/BatchNo  (None, 32, 32, 120)  480        ['expanded_conv_4/expand[0][0]']
#  rm (BatchNormalization)
#
#  re_lu_329 (ReLU)               (None, 32, 32, 120)  0           ['expanded_conv_4/expand/BatchNor
#                                                                  m[0][0]']
#
#  expanded_conv_4/depthwise (Dep  (None, 32, 32, 120)  3000       ['re_lu_329[0][0]']
#  thwiseConv2D)
#
#  expanded_conv_4/depthwise/Batc  (None, 32, 32, 120)  480        ['expanded_conv_4/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  re_lu_330 (ReLU)               (None, 32, 32, 120)  0           ['expanded_conv_4/depthwise/Batch
#                                                                  Norm[0][0]']
#
#  expanded_conv_4/squeeze_excite  (None, 1, 1, 120)   0           ['re_lu_330[0][0]']
#  /AvgPool (GlobalAveragePooling
#  2D)
#
#  expanded_conv_4/squeeze_excite  (None, 1, 1, 32)    3872        ['expanded_conv_4/squeeze_excite/
#  /Conv (Conv2D)                                                  AvgPool[0][0]']
#
#  expanded_conv_4/squeeze_excite  (None, 1, 1, 32)    0           ['expanded_conv_4/squeeze_excite/
#  /Relu (ReLU)                                                    Conv[0][0]']
#
#  expanded_conv_4/squeeze_excite  (None, 1, 1, 120)   3960        ['expanded_conv_4/squeeze_excite/
#  /Conv_1 (Conv2D)                                                Relu[0][0]']
#
#  tf.__operators__.add_234 (TFOp  (None, 1, 1, 120)   0           ['expanded_conv_4/squeeze_excite/
#  Lambda)                                                         Conv_1[0][0]']
#
#  re_lu_331 (ReLU)               (None, 1, 1, 120)    0           ['tf.__operators__.add_234[0][0]'
#                                                                  ]
#
#  tf.math.multiply_234 (TFOpLamb  (None, 1, 1, 120)   0           ['re_lu_331[0][0]']
#  da)
#
#  expanded_conv_4/squeeze_excite  (None, 32, 32, 120)  0          ['re_lu_330[0][0]',
#  /Mul (Multiply)                                                  'tf.math.multiply_234[0][0]']
#
#  expanded_conv_4/project (Conv2  (None, 32, 32, 40)  4800        ['expanded_conv_4/squeeze_excite/
#  D)                                                              Mul[0][0]']
#
#  expanded_conv_4/project/BatchN  (None, 32, 32, 40)  160         ['expanded_conv_4/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_4/Add (Add)      (None, 32, 32, 40)   0           ['expanded_conv_3/project/BatchNo
#                                                                  rm[0][0]',
#                                                                   'expanded_conv_4/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_5/expand (Conv2D  (None, 32, 32, 120)  4800       ['expanded_conv_4/Add[0][0]']
#  )
#
#  expanded_conv_5/expand/BatchNo  (None, 32, 32, 120)  480        ['expanded_conv_5/expand[0][0]']
#  rm (BatchNormalization)
#
#  re_lu_332 (ReLU)               (None, 32, 32, 120)  0           ['expanded_conv_5/expand/BatchNor
#                                                                  m[0][0]']
#
#  expanded_conv_5/depthwise (Dep  (None, 32, 32, 120)  3000       ['re_lu_332[0][0]']
#  thwiseConv2D)
#
#  expanded_conv_5/depthwise/Batc  (None, 32, 32, 120)  480        ['expanded_conv_5/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  re_lu_333 (ReLU)               (None, 32, 32, 120)  0           ['expanded_conv_5/depthwise/Batch
#                                                                  Norm[0][0]']
#
#  expanded_conv_5/squeeze_excite  (None, 1, 1, 120)   0           ['re_lu_333[0][0]']
#  /AvgPool (GlobalAveragePooling
#  2D)
#
#  expanded_conv_5/squeeze_excite  (None, 1, 1, 32)    3872        ['expanded_conv_5/squeeze_excite/
#  /Conv (Conv2D)                                                  AvgPool[0][0]']
#
#  expanded_conv_5/squeeze_excite  (None, 1, 1, 32)    0           ['expanded_conv_5/squeeze_excite/
#  /Relu (ReLU)                                                    Conv[0][0]']
#
#  expanded_conv_5/squeeze_excite  (None, 1, 1, 120)   3960        ['expanded_conv_5/squeeze_excite/
#  /Conv_1 (Conv2D)                                                Relu[0][0]']
#
#  tf.__operators__.add_235 (TFOp  (None, 1, 1, 120)   0           ['expanded_conv_5/squeeze_excite/
#  Lambda)                                                         Conv_1[0][0]']
#
#  re_lu_334 (ReLU)               (None, 1, 1, 120)    0           ['tf.__operators__.add_235[0][0]'
#                                                                  ]
#
#  tf.math.multiply_235 (TFOpLamb  (None, 1, 1, 120)   0           ['re_lu_334[0][0]']
#  da)
#
#  expanded_conv_5/squeeze_excite  (None, 32, 32, 120)  0          ['re_lu_333[0][0]',
#  /Mul (Multiply)                                                  'tf.math.multiply_235[0][0]']
#
#  expanded_conv_5/project (Conv2  (None, 32, 32, 40)  4800        ['expanded_conv_5/squeeze_excite/
#  D)                                                              Mul[0][0]']
#
#  expanded_conv_5/project/BatchN  (None, 32, 32, 40)  160         ['expanded_conv_5/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_5/Add (Add)      (None, 32, 32, 40)   0           ['expanded_conv_4/Add[0][0]',
#                                                                   'expanded_conv_5/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_6/expand (Conv2D  (None, 32, 32, 240)  9600       ['expanded_conv_5/Add[0][0]']
#  )
#
#  expanded_conv_6/expand/BatchNo  (None, 32, 32, 240)  960        ['expanded_conv_6/expand[0][0]']
#  rm (BatchNormalization)
#
#  tf.__operators__.add_236 (TFOp  (None, 32, 32, 240)  0          ['expanded_conv_6/expand/BatchNor
#  Lambda)                                                         m[0][0]']
#
#  re_lu_335 (ReLU)               (None, 32, 32, 240)  0           ['tf.__operators__.add_236[0][0]'
#                                                                  ]
#
#  tf.math.multiply_236 (TFOpLamb  (None, 32, 32, 240)  0          ['re_lu_335[0][0]']
#  da)
#
#  multiply_169 (Multiply)        (None, 32, 32, 240)  0           ['expanded_conv_6/expand/BatchNor
#                                                                  m[0][0]',
#                                                                   'tf.math.multiply_236[0][0]']
#
#  expanded_conv_6/depthwise/pad   (None, 33, 33, 240)  0          ['multiply_169[0][0]']
#  (ZeroPadding2D)
#
#  expanded_conv_6/depthwise (Dep  (None, 16, 16, 240)  2160       ['expanded_conv_6/depthwise/pad[0
#  thwiseConv2D)                                                   ][0]']
#
#  expanded_conv_6/depthwise/Batc  (None, 16, 16, 240)  960        ['expanded_conv_6/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  tf.__operators__.add_237 (TFOp  (None, 16, 16, 240)  0          ['expanded_conv_6/depthwise/Batch
#  Lambda)                                                         Norm[0][0]']
#
#  re_lu_336 (ReLU)               (None, 16, 16, 240)  0           ['tf.__operators__.add_237[0][0]'
#                                                                  ]
#
#  tf.math.multiply_237 (TFOpLamb  (None, 16, 16, 240)  0          ['re_lu_336[0][0]']
#  da)
#
#  multiply_170 (Multiply)        (None, 16, 16, 240)  0           ['expanded_conv_6/depthwise/Batch
#                                                                  Norm[0][0]',
#                                                                   'tf.math.multiply_237[0][0]']
#
#  expanded_conv_6/project (Conv2  (None, 16, 16, 80)  19200       ['multiply_170[0][0]']
#  D)
#
#  expanded_conv_6/project/BatchN  (None, 16, 16, 80)  320         ['expanded_conv_6/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_7/expand (Conv2D  (None, 16, 16, 200)  16000      ['expanded_conv_6/project/BatchNo
#  )                                                               rm[0][0]']
#
#  expanded_conv_7/expand/BatchNo  (None, 16, 16, 200)  800        ['expanded_conv_7/expand[0][0]']
#  rm (BatchNormalization)
#
#  tf.__operators__.add_238 (TFOp  (None, 16, 16, 200)  0          ['expanded_conv_7/expand/BatchNor
#  Lambda)                                                         m[0][0]']
#
#  re_lu_337 (ReLU)               (None, 16, 16, 200)  0           ['tf.__operators__.add_238[0][0]'
#                                                                  ]
#
#  tf.math.multiply_238 (TFOpLamb  (None, 16, 16, 200)  0          ['re_lu_337[0][0]']
#  da)
#
#  multiply_171 (Multiply)        (None, 16, 16, 200)  0           ['expanded_conv_7/expand/BatchNor
#                                                                  m[0][0]',
#                                                                   'tf.math.multiply_238[0][0]']
#
#  expanded_conv_7/depthwise (Dep  (None, 16, 16, 200)  1800       ['multiply_171[0][0]']
#  thwiseConv2D)
#
#  expanded_conv_7/depthwise/Batc  (None, 16, 16, 200)  800        ['expanded_conv_7/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  tf.__operators__.add_239 (TFOp  (None, 16, 16, 200)  0          ['expanded_conv_7/depthwise/Batch
#  Lambda)                                                         Norm[0][0]']
#
#  re_lu_338 (ReLU)               (None, 16, 16, 200)  0           ['tf.__operators__.add_239[0][0]'
#                                                                  ]
#
#  tf.math.multiply_239 (TFOpLamb  (None, 16, 16, 200)  0          ['re_lu_338[0][0]']
#  da)
#
#  multiply_172 (Multiply)        (None, 16, 16, 200)  0           ['expanded_conv_7/depthwise/Batch
#                                                                  Norm[0][0]',
#                                                                   'tf.math.multiply_239[0][0]']
#
#  expanded_conv_7/project (Conv2  (None, 16, 16, 80)  16000       ['multiply_172[0][0]']
#  D)
#
#  expanded_conv_7/project/BatchN  (None, 16, 16, 80)  320         ['expanded_conv_7/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_7/Add (Add)      (None, 16, 16, 80)   0           ['expanded_conv_6/project/BatchNo
#                                                                  rm[0][0]',
#                                                                   'expanded_conv_7/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_8/expand (Conv2D  (None, 16, 16, 184)  14720      ['expanded_conv_7/Add[0][0]']
#  )
#
#  expanded_conv_8/expand/BatchNo  (None, 16, 16, 184)  736        ['expanded_conv_8/expand[0][0]']
#  rm (BatchNormalization)
#
#  tf.__operators__.add_240 (TFOp  (None, 16, 16, 184)  0          ['expanded_conv_8/expand/BatchNor
#  Lambda)                                                         m[0][0]']
#
#  re_lu_339 (ReLU)               (None, 16, 16, 184)  0           ['tf.__operators__.add_240[0][0]'
#                                                                  ]
#
#  tf.math.multiply_240 (TFOpLamb  (None, 16, 16, 184)  0          ['re_lu_339[0][0]']
#  da)
#
#  multiply_173 (Multiply)        (None, 16, 16, 184)  0           ['expanded_conv_8/expand/BatchNor
#                                                                  m[0][0]',
#                                                                   'tf.math.multiply_240[0][0]']
#
#  expanded_conv_8/depthwise (Dep  (None, 16, 16, 184)  1656       ['multiply_173[0][0]']
#  thwiseConv2D)
#
#  expanded_conv_8/depthwise/Batc  (None, 16, 16, 184)  736        ['expanded_conv_8/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  tf.__operators__.add_241 (TFOp  (None, 16, 16, 184)  0          ['expanded_conv_8/depthwise/Batch
#  Lambda)                                                         Norm[0][0]']
#
#  re_lu_340 (ReLU)               (None, 16, 16, 184)  0           ['tf.__operators__.add_241[0][0]'
#                                                                  ]
#
#  tf.math.multiply_241 (TFOpLamb  (None, 16, 16, 184)  0          ['re_lu_340[0][0]']
#  da)
#
#  multiply_174 (Multiply)        (None, 16, 16, 184)  0           ['expanded_conv_8/depthwise/Batch
#                                                                  Norm[0][0]',
#                                                                   'tf.math.multiply_241[0][0]']
#
#  expanded_conv_8/project (Conv2  (None, 16, 16, 80)  14720       ['multiply_174[0][0]']
#  D)
#
#  expanded_conv_8/project/BatchN  (None, 16, 16, 80)  320         ['expanded_conv_8/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_8/Add (Add)      (None, 16, 16, 80)   0           ['expanded_conv_7/Add[0][0]',
#                                                                   'expanded_conv_8/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_9/expand (Conv2D  (None, 16, 16, 184)  14720      ['expanded_conv_8/Add[0][0]']
#  )
#
#  expanded_conv_9/expand/BatchNo  (None, 16, 16, 184)  736        ['expanded_conv_9/expand[0][0]']
#  rm (BatchNormalization)
#
#  tf.__operators__.add_242 (TFOp  (None, 16, 16, 184)  0          ['expanded_conv_9/expand/BatchNor
#  Lambda)                                                         m[0][0]']
#
#  re_lu_341 (ReLU)               (None, 16, 16, 184)  0           ['tf.__operators__.add_242[0][0]'
#                                                                  ]
#
#  tf.math.multiply_242 (TFOpLamb  (None, 16, 16, 184)  0          ['re_lu_341[0][0]']
#  da)
#
#  multiply_175 (Multiply)        (None, 16, 16, 184)  0           ['expanded_conv_9/expand/BatchNor
#                                                                  m[0][0]',
#                                                                   'tf.math.multiply_242[0][0]']
#
#  expanded_conv_9/depthwise (Dep  (None, 16, 16, 184)  1656       ['multiply_175[0][0]']
#  thwiseConv2D)
#
#  expanded_conv_9/depthwise/Batc  (None, 16, 16, 184)  736        ['expanded_conv_9/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  tf.__operators__.add_243 (TFOp  (None, 16, 16, 184)  0          ['expanded_conv_9/depthwise/Batch
#  Lambda)                                                         Norm[0][0]']
#
#  re_lu_342 (ReLU)               (None, 16, 16, 184)  0           ['tf.__operators__.add_243[0][0]'
#                                                                  ]
#
#  tf.math.multiply_243 (TFOpLamb  (None, 16, 16, 184)  0          ['re_lu_342[0][0]']
#  da)
#
#  multiply_176 (Multiply)        (None, 16, 16, 184)  0           ['expanded_conv_9/depthwise/Batch
#                                                                  Norm[0][0]',
#                                                                   'tf.math.multiply_243[0][0]']
#
#  expanded_conv_9/project (Conv2  (None, 16, 16, 80)  14720       ['multiply_176[0][0]']
#  D)
#
#  expanded_conv_9/project/BatchN  (None, 16, 16, 80)  320         ['expanded_conv_9/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_9/Add (Add)      (None, 16, 16, 80)   0           ['expanded_conv_8/Add[0][0]',
#                                                                   'expanded_conv_9/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_10/expand (Conv2  (None, 16, 16, 480)  38400      ['expanded_conv_9/Add[0][0]']
#  D)
#
#  expanded_conv_10/expand/BatchN  (None, 16, 16, 480)  1920       ['expanded_conv_10/expand[0][0]']
#  orm (BatchNormalization)
#
#  tf.__operators__.add_244 (TFOp  (None, 16, 16, 480)  0          ['expanded_conv_10/expand/BatchNo
#  Lambda)                                                         rm[0][0]']
#
#  re_lu_343 (ReLU)               (None, 16, 16, 480)  0           ['tf.__operators__.add_244[0][0]'
#                                                                  ]
#
#  tf.math.multiply_244 (TFOpLamb  (None, 16, 16, 480)  0          ['re_lu_343[0][0]']
#  da)
#
#  multiply_177 (Multiply)        (None, 16, 16, 480)  0           ['expanded_conv_10/expand/BatchNo
#                                                                  rm[0][0]',
#                                                                   'tf.math.multiply_244[0][0]']
#
#  expanded_conv_10/depthwise (De  (None, 16, 16, 480)  4320       ['multiply_177[0][0]']
#  pthwiseConv2D)
#
#  expanded_conv_10/depthwise/Bat  (None, 16, 16, 480)  1920       ['expanded_conv_10/depthwise[0][0
#  chNorm (BatchNormalization)                                     ]']
#
#  tf.__operators__.add_245 (TFOp  (None, 16, 16, 480)  0          ['expanded_conv_10/depthwise/Batc
#  Lambda)                                                         hNorm[0][0]']
#
#  re_lu_344 (ReLU)               (None, 16, 16, 480)  0           ['tf.__operators__.add_245[0][0]'
# ...
#  expanded_conv_13/squeeze_excit  (None, 1, 1, 960)   0           ['multiply_184[0][0]']
#  e/AvgPool (GlobalAveragePoolin
#  g2D)
#
#  expanded_conv_13/squeeze_excit  (None, 1, 1, 240)   230640      ['expanded_conv_13/squeeze_excite
#  e/Conv (Conv2D)                                                 /AvgPool[0][0]']
#
#  expanded_conv_13/squeeze_excit  (None, 1, 1, 240)   0           ['expanded_conv_13/squeeze_excite
#  e/Relu (ReLU)                                                   /Conv[0][0]']
#
#  expanded_conv_13/squeeze_excit  (None, 1, 1, 960)   231360      ['expanded_conv_13/squeeze_excite
#  e/Conv_1 (Conv2D)                                               /Relu[0][0]']
#
#  tf.__operators__.add_255 (TFOp  (None, 1, 1, 960)   0           ['expanded_conv_13/squeeze_excite
#  Lambda)                                                         /Conv_1[0][0]']
#
#  re_lu_354 (ReLU)               (None, 1, 1, 960)    0           ['tf.__operators__.add_255[0][0]'
#                                                                  ]
#
#  tf.math.multiply_255 (TFOpLamb  (None, 1, 1, 960)   0           ['re_lu_354[0][0]']
#  da)
#
#  expanded_conv_13/squeeze_excit  (None, 8, 8, 960)   0           ['multiply_184[0][0]',
#  e/Mul (Multiply)                                                 'tf.math.multiply_255[0][0]']
#
#  expanded_conv_13/project (Conv  (None, 8, 8, 160)   153600      ['expanded_conv_13/squeeze_excite
#  2D)                                                             /Mul[0][0]']
#
#  expanded_conv_13/project/Batch  (None, 8, 8, 160)   640         ['expanded_conv_13/project[0][0]'
#  Norm (BatchNormalization)                                       ]
#
#  expanded_conv_13/Add (Add)     (None, 8, 8, 160)    0           ['expanded_conv_12/project/BatchN
#                                                                  orm[0][0]',
#                                                                   'expanded_conv_13/project/BatchN
#                                                                  orm[0][0]']
#
#  expanded_conv_14/expand (Conv2  (None, 8, 8, 960)   153600      ['expanded_conv_13/Add[0][0]']
#  D)
#
#  expanded_conv_14/expand/BatchN  (None, 8, 8, 960)   3840        ['expanded_conv_14/expand[0][0]']
#  orm (BatchNormalization)
#
#  tf.__operators__.add_256 (TFOp  (None, 8, 8, 960)   0           ['expanded_conv_14/expand/BatchNo
#  Lambda)                                                         rm[0][0]']
#
#  re_lu_355 (ReLU)               (None, 8, 8, 960)    0           ['tf.__operators__.add_256[0][0]'
#                                                                  ]
#
#  tf.math.multiply_256 (TFOpLamb  (None, 8, 8, 960)   0           ['re_lu_355[0][0]']
#  da)
#
#  multiply_185 (Multiply)        (None, 8, 8, 960)    0           ['expanded_conv_14/expand/BatchNo
#                                                                  rm[0][0]',
#                                                                   'tf.math.multiply_256[0][0]']
#
#  expanded_conv_14/depthwise (De  (None, 8, 8, 960)   24000       ['multiply_185[0][0]']
#  pthwiseConv2D)
#
#  expanded_conv_14/depthwise/Bat  (None, 8, 8, 960)   3840        ['expanded_conv_14/depthwise[0][0
#  chNorm (BatchNormalization)                                     ]']
#
#  tf.__operators__.add_257 (TFOp  (None, 8, 8, 960)   0           ['expanded_conv_14/depthwise/Batc
#  Lambda)                                                         hNorm[0][0]']
#
#  re_lu_356 (ReLU)               (None, 8, 8, 960)    0           ['tf.__operators__.add_257[0][0]'
#                                                                  ]
#
#  tf.math.multiply_257 (TFOpLamb  (None, 8, 8, 960)   0           ['re_lu_356[0][0]']
#  da)
#
#  multiply_186 (Multiply)        (None, 8, 8, 960)    0           ['expanded_conv_14/depthwise/Batc
#                                                                  hNorm[0][0]',
#                                                                   'tf.math.multiply_257[0][0]']
#
#  expanded_conv_14/squeeze_excit  (None, 1, 1, 960)   0           ['multiply_186[0][0]']
#  e/AvgPool (GlobalAveragePoolin
#  g2D)
#
#  expanded_conv_14/squeeze_excit  (None, 1, 1, 240)   230640      ['expanded_conv_14/squeeze_excite
#  e/Conv (Conv2D)                                                 /AvgPool[0][0]']
#
#  expanded_conv_14/squeeze_excit  (None, 1, 1, 240)   0           ['expanded_conv_14/squeeze_excite
#  e/Relu (ReLU)                                                   /Conv[0][0]']
#
#  expanded_conv_14/squeeze_excit  (None, 1, 1, 960)   231360      ['expanded_conv_14/squeeze_excite
#  e/Conv_1 (Conv2D)                                               /Relu[0][0]']
#
#  tf.__operators__.add_258 (TFOp  (None, 1, 1, 960)   0           ['expanded_conv_14/squeeze_excite
#  Lambda)                                                         /Conv_1[0][0]']
#
#  re_lu_357 (ReLU)               (None, 1, 1, 960)    0           ['tf.__operators__.add_258[0][0]'
#                                                                  ]
#
#  tf.math.multiply_258 (TFOpLamb  (None, 1, 1, 960)   0           ['re_lu_357[0][0]']
#  da)
#
#  expanded_conv_14/squeeze_excit  (None, 8, 8, 960)   0           ['multiply_186[0][0]',
#  e/Mul (Multiply)                                                 'tf.math.multiply_258[0][0]']
#
#  expanded_conv_14/project (Conv  (None, 8, 8, 160)   153600      ['expanded_conv_14/squeeze_excite
#  2D)                                                             /Mul[0][0]']
#
#  expanded_conv_14/project/Batch  (None, 8, 8, 160)   640         ['expanded_conv_14/project[0][0]'
#  Norm (BatchNormalization)                                       ]
#
#  expanded_conv_14/Add (Add)     (None, 8, 8, 160)    0           ['expanded_conv_13/Add[0][0]',
#                                                                   'expanded_conv_14/project/BatchN
#                                                                  orm[0][0]']
#
#  Conv_1 (Conv2D)                (None, 8, 8, 960)    153600      ['expanded_conv_14/Add[0][0]']
#
#  Conv_1/BatchNorm (BatchNormali  (None, 8, 8, 960)   3840        ['Conv_1[0][0]']
#  zation)
#
#  tf.__operators__.add_259 (TFOp  (None, 8, 8, 960)   0           ['Conv_1/BatchNorm[0][0]']
#  Lambda)
#
#  re_lu_358 (ReLU)               (None, 8, 8, 960)    0           ['tf.__operators__.add_259[0][0]'
#                                                                  ]
#
#  tf.math.multiply_259 (TFOpLamb  (None, 8, 8, 960)   0           ['re_lu_358[0][0]']
#  da)
#
#  multiply_187 (Multiply)        (None, 8, 8, 960)    0           ['Conv_1/BatchNorm[0][0]',
#                                                                   'tf.math.multiply_259[0][0]']
#
#  global_average_pooling2d_16 (G  (None, 1, 1, 960)   0           ['multiply_187[0][0]']
#  lobalAveragePooling2D)
#
#  Conv_2 (Conv2D)                (None, 1, 1, 1280)   1230080     ['global_average_pooling2d_16[0][
#                                                                  0]']
#
#  tf.__operators__.add_260 (TFOp  (None, 1, 1, 1280)  0           ['Conv_2[0][0]']
#  Lambda)
#
#  re_lu_359 (ReLU)               (None, 1, 1, 1280)   0           ['tf.__operators__.add_260[0][0]'
#                                                                  ]
#
#  tf.math.multiply_260 (TFOpLamb  (None, 1, 1, 1280)  0           ['re_lu_359[0][0]']
#  da)
#
#  multiply_188 (Multiply)        (None, 1, 1, 1280)   0           ['Conv_2[0][0]',
#                                                                   'tf.math.multiply_260[0][0]']
#
#  dropout_16 (Dropout)           (None, 1, 1, 1280)   0           ['multiply_188[0][0]']
#
#  global_average_pooling2d_17 (G  (None, 1280)        0           ['dropout_16[0][0]']
#  lobalAveragePooling2D)
#
#  batch_normalization_8 (BatchNo  (None, 1280)        5120        ['global_average_pooling2d_17[0][
#  rmalization)                                                    0]']
#
#  dense_16 (Dense)               (None, 256)          327936      ['batch_normalization_8[0][0]']
#
#  dropout_17 (Dropout)           (None, 256)          0           ['dense_16[0][0]']
#
#  dense_17 (Dense)               (None, 9)            2313        ['dropout_17[0][0]']
#
# ==================================================================================================
# Total params: 4,561,801
# Trainable params: 1,562,889
# Non-trainable params: 2,998,912
# __________________________________________________________________________________________________

# %% [markdown]
# ##**Model Evaluation**

# %%
plt.plot(range(0, epochs), history.history["loss"], color="b", label="Loss")
plt.plot(range(0, epochs), history.history["val_loss"], color="r", label="Test Loss")
plt.legend()
plt.show()

# %%
plt.plot(range(0, epochs), history.history["accuracy"], color="b", label="Accuracy")
plt.plot(range(0, epochs), history.history["val_accuracy"], color="r", label="Test Accuracy")
plt.legend()
plt.show()

# %%
plt.xlim([0, 0.003])
learning_rates = 1e-3 * (10 ** (np.arange(epochs) / 30))
plt.plot(learning_rates, history.history['loss'], lw=3, color='#48e073')
plt.title('Learning rate vs. loss', size=20)
plt.xlabel('Learning rate', size=14)
plt.ylabel('Loss', size=14)
# Out:
# Text(0, 0.5, 'Loss')

# %%
import requests

img_data = requests.get("https://images.unsplash.com/photo-1591872203534-278fc084969e?ixlib=rb-1.2.1&ixid=MnwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8&auto=format&fit=crop&w=1064&q=80").content
with open('img.jpg', 'wb') as handler:
    handler.write(img_data)

path = "/content/img.jpg"

img = tf.keras.preprocessing.image.load_img(path, target_size=(256, 256))
img_array = tf.keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) 

predictions = model.predict(img_array)

plt.imshow(img)
print(predictions[0]*100, "\n", classes)
print("Prediction: ", classes[np.argmax(predictions)], f"{predictions[0][np.argmax(predictions)]*100}%")
# Out:
# [1.1614963e-01 1.0170896e+00 3.3458400e-01 3.6209685e-01 9.5969460e+01
#  5.7956848e-02 1.9298062e+00 8.9533217e-02 1.2331158e-01]
#  ['Aluminium', 'Carton', 'Glass', 'Organic Waste', 'Other Plastics', 'Paper and Cardboard', 'Plastic', 'Textiles', 'Wood']
# Prediction:  Other Plastics 95.96946239471436%

# %%
def plot_confusion_matrix(cm, target_names, cmap=None):
    import matplotlib.pyplot as plt
    import numpy as np
    import itertools

    accuracy = np.trace(cm) / float(np.sum(cm))
    misclass = 1 - accuracy

    if cmap is None:
        cmap = plt.get_cmap('Blues')

    plt.figure(figsize=(8, 6))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title('Confusion matrix')
    plt.colorbar()

    if target_names is not None:
        tick_marks = np.arange(len(target_names))
        plt.xticks(tick_marks, target_names, rotation=45)
        plt.yticks(tick_marks, target_names)

    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
            plt.text(j, i, "{:,}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label\naccuracy={:0.4f}%; misclass={:0.4f}%'.format(accuracy, misclass))
    plt.show()

plt.figure(figsize=(10, 10))
true = []
predictions = []

"""
for images, labels in test_dataset.take(50):
  pred = model.predict(images)
  for i in range(32):
    try:
      ax = plt.subplot(4, 8, i + 1)
      plt.imshow(images[i].numpy().astype("uint8"))
      #print(classes[np.argmax(pred[i])], 100 * np.max(pred[i]), "real = " + str(classes[labels[i]]))

      true.append(labels[i])
      predictions.append(np.argmax(pred[i]))

      plt.title(classes[labels[i]])
      plt.axis("off")
    except:
      print()

"""
path = "/content/WasteClassificationNeuralNetwork/WasteImagesDataset"
for i in os.listdir(path):
  folderPath = os.path.join(path, i)
  for j in os.listdir(folderPath)[:550]:
    fullPath = os.path.join(folderPath, j)
    try:
      img = tf.keras.preprocessing.image.load_img(fullPath, target_size=(256, 256))
      img_array = tf.keras.preprocessing.image.img_to_array(img)
      img_array = tf.expand_dims(img_array, 0) 

      preds = model.predict(img_array)
      true.append(classes.index(i))
      predictions.append(np.argmax(preds))
    except:
      print("Error on image:", fullPath)

plot_confusion_matrix(tf.math.confusion_matrix(true, predictions), classes)
